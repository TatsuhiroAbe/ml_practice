# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
plt.style.use('ggplot')
import seaborn as sns

# %%
df = pd.read_csv('train.csv', nrows=550000)
df.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count
# 0                1
# 1                1
# 2                2
# 3                1
# 4                1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550000 entries, 0 to 549999
# Data columns (total 8 columns):
# key                  550000 non-null object
# fare_amount          550000 non-null float64
# pickup_datetime      550000 non-null object
# pickup_longitude     550000 non-null float64
# pickup_latitude      550000 non-null float64
# dropoff_longitude    549994 non-null float64
# dropoff_latitude     549994 non-null float64
# passenger_count      550000 non-null int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 33.6+ MB

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  550000.000000     550000.000000    550000.000000      549994.000000
# mean       11.348953        -72.527701        39.922421         -72.524337
# std         9.883326         12.545991         7.950921          11.692485
# min       -44.900000      -3377.680935     -3116.285383       -3383.296608
# 25%         6.000000        -73.992043        40.734942         -73.991390
# 50%         8.500000        -73.981790        40.752681         -73.980141
# 75%        12.500000        -73.967108        40.767092         -73.963602
# max       500.000000       2140.601160      1703.092772          40.851027
#
#        dropoff_latitude  passenger_count
# count     549994.000000    550000.000000
# mean          39.917940         1.683707
# std            7.297479         1.307607
# min        -2559.748913         0.000000
# 25%           40.734060         1.000000
# 50%           40.753135         1.000000
# 75%           40.768124         2.000000
# max          404.616667         6.000000

# %%
df.isnull().sum()
# Out:
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    6
# dropoff_latitude     6
# passenger_count      0
# dtype: int64

# %%
df = df.dropna()
df.shape
# Out:
# (549994, 8)

# %%
df = df[df['fare_amount'] > 0]
df.shape
# Out:
# (549954, 8)

# %%
plt.figure(figsize=(12, 8))
plt.hist(df['fare_amount'], bins=100)
plt.show()

# %%
df = df[df['fare_amount'] < 100]
plt.figure(figsize=(12, 8))
plt.hist(df['fare_amount'], bins=100)
plt.show()

# %%
def outlier_iqr(df, columns=None):
    if columns == None:
        columns = df.columns

    for col in columns:
        q1 = df[col].describe()['25%']
        q3 = df[col].describe()['75%']
        #四分位範囲
        iqr = q3 - q1 
        
        outlier_min = q1 - iqr * 1.5
        outlier_max = q3 + iqr * 1.5

        # 範囲から外れている値を除く
        df = df[(df[col] >= outlier_min) & (df[col] <= outlier_max)]
        
    return df

# %%
print('before', df.shape)
df = outlier_iqr(df, columns=['fare_amount'])
print('after', df.shape)
# Out:
# before (549707, 8)
# after (502410, 8)

# %%
plt.figure(figsize=(12, 8))
plt.hist(df['fare_amount'], bins=50)
plt.show()

# %%
print('before', df.shape)
df = df[(df['pickup_longitude'] > -75) & (df['pickup_longitude'] < -73)]
df = df[(df['pickup_latitude'] > 40) & (df['pickup_latitude'] < 42)]
df = df[(df['dropoff_longitude'] > -75) & (df['dropoff_longitude'] < -73)]
df = df[(df['dropoff_latitude'] > 40) & (df['dropoff_latitude'] < 42)]
print('after', df.shape)
# Out:
# before (502410, 8)
# after (492133, 8)

# %%
df['passenger_count'].value_counts()
# Out:
# 1    341337
# 2     72056
# 5     34752
# 3     21456
# 4     10411
# 6     10253
# 0      1868
# Name: passenger_count, dtype: int64

# %%
print('before', df.shape)
df = df[(df['passenger_count'] > 0)]
print('after', df.shape)
# Out:
# before (492133, 8)
# after (490265, 8)

# %%
df.describe()
# Out:
#          fare_amount  pickup_longitude  pickup_latitude  dropoff_longitude  \
# count  490265.000000     490265.000000    490265.000000      490265.000000
# mean        8.933894        -73.979709        40.752227         -73.978072
# std         4.139031          0.028164         0.027131           0.028387
# min         0.010000        -74.968142        40.052722         -74.964263
# 25%         5.700000        -73.992532        40.737282         -73.991863
# 50%         8.000000        -73.982429        40.753330         -73.981329
# 75%        11.000000        -73.970177        40.766867         -73.967958
# max        22.250000        -73.036247        41.800252         -73.029770
#
#        dropoff_latitude  passenger_count
# count     490265.000000    490265.000000
# mean          40.752539         1.686310
# std            0.028941         1.303497
# min           40.041180         1.000000
# 25%           40.737189         1.000000
# 50%           40.753990         1.000000
# 75%           40.767942         2.000000
# max           41.923820         6.000000

# %%
def calculation_distance(x_1, y_1, x_2, y_2):
    # 赤道半径 (km)
    R = 6371
    # Radian角に変換
    _x1, _y1, _x2, _y2  = map(np.radians, [x_1, y_1, x_2, y_2])
    
    delta_x = _x2 - _x1
    delta_y = _y2 - _y1
    
    # 距離を計算
    a = np.sin(delta_y/2.0)**2 + np.cos(_y1) * np.cos(_y2) * np.sin(delta_x/2.0)**2
    return 2 * R * np.arcsin(np.sqrt(a))

def calculation_azimuth(x_1, y_1, x_2, y_2):
    # Radian角に修正
    _x1, _y1, _x2, _y2 = map(np.radians, [x_1, y_1, x_2, y_2])
    
    delta_x = _x2 - _x1
    _y = np.sin(delta_x)
    _x = np.cos(_y1) * np.tan(_y2) - np.sin(_y1) * np.cos(delta_x)

    psi = np.rad2deg(np.arctan2(_y, _x))
    
    return np.where(psi < 0, 360 + psi, psi)

# %%
df['distance'] = calculation_distance(df['pickup_longitude'],
                                      df['pickup_latitude'],
                                      df['dropoff_longitude'],
                                      df['dropoff_latitude'])
df.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance
# 0                1  1.030764
# 1                1  8.450134
# 2                2  1.389525
# 3                1  2.799270
# 4                1  1.999157

# %%
df['azimuth'] = calculation_azimuth(df['pickup_longitude'],
                                    df['pickup_latitude'],
                                    df['dropoff_longitude'],
                                    df['dropoff_latitude'])
df.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5  2009-06-15 17:26:21 UTC
# 1    2010-01-05 16:52:16.0000002         16.9  2010-01-05 16:52:16 UTC
# 2   2011-08-18 00:35:00.00000049          5.7  2011-08-18 00:35:00 UTC
# 3    2012-04-21 04:30:42.0000001          7.7  2012-04-21 04:30:42 UTC
# 4  2010-03-09 07:51:00.000000135          5.3  2010-03-09 07:51:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance     azimuth
# 0                1  1.030764  167.240469
# 1                1  8.450134   21.498365
# 2                2  1.389525  211.033211
# 3                1  2.799270  352.327836
# 4                1  1.999157   28.802783

# %%
df['pickup_datetime'] = pd.to_datetime(df['pickup_datetime'], format='%Y-%m-%d %H:%M:%S UTC')

df['hour'] = df['pickup_datetime'].dt.hour
df['day'] = df['pickup_datetime'].dt.day
df['month'] = df['pickup_datetime'].dt.month
df['dayofweek'] = df['pickup_datetime'].dt.dayofweek
df['year'] = df['pickup_datetime'].dt.year

df.head()
# Out:
#                              key  fare_amount     pickup_datetime  \
# 0    2009-06-15 17:26:21.0000001          4.5 2009-06-15 17:26:21
# 1    2010-01-05 16:52:16.0000002         16.9 2010-01-05 16:52:16
# 2   2011-08-18 00:35:00.00000049          5.7 2011-08-18 00:35:00
# 3    2012-04-21 04:30:42.0000001          7.7 2012-04-21 04:30:42
# 4  2010-03-09 07:51:00.000000135          5.3 2010-03-09 07:51:00
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.844311        40.721319         -73.841610         40.712278
# 1        -74.016048        40.711303         -73.979268         40.782004
# 2        -73.982738        40.761270         -73.991242         40.750562
# 3        -73.987130        40.733143         -73.991567         40.758092
# 4        -73.968095        40.768008         -73.956655         40.783762
#
#    passenger_count  distance     azimuth  hour  day  month  dayofweek  year
# 0                1  1.030764  167.240469    17   15      6          0  2009
# 1                1  8.450134   21.498365    16    5      1          1  2010
# 2                2  1.389525  211.033211     0   18      8          3  2011
# 3                1  2.799270  352.327836     4   21      4          5  2012
# 4                1  1.999157   28.802783     7    9      3          1  2010

# %%
from sklearn.model_selection import train_test_split
import xgboost as xgb

# %%
X = df.drop(columns=['key', 'fare_amount', 'pickup_datetime'])
y = df['fare_amount']

print(X.shape)
print(y.shape)
# Out:
# (490265, 12)
# (490265,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    random_state=0)
print(X_train.shape)
print(X_test.shape)
# Out:
# (392212, 12)
# (98053, 12)

# %%
params = {
    'silent': 1,
    'max_depth': 6,
    'min_child_weight': 1,
    'eta': 0.1,
    'tree_method': 'exact',
    'objective': 'reg:linear',
    'eval_metric': 'rmse',
    'predictor': 'cpu_predictor'
}

# params = {
#     'silent': 1,
#     'max_depth': 6,
#     'min_child_weight': 1,
#     'eta': 0.1,
#     'tree_method': 'gpu_exact',
#     'objective': 'gpu:reg:linear',
#     'eval_metric': 'rmse',
#     'predictor': 'gpu_predictor'
# }

dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)
model = xgb.train(params=params,
                  dtrain=dtrain,
                  num_boost_round=1000,
                  early_stopping_rounds=5,
                  evals=[(dtest, 'test')])
# Out:
# [0]	test-rmse:8.518
# Will train until test-rmse hasn't improved in 5 rounds.
# [1]	test-rmse:7.72211
# [2]	test-rmse:7.01123
# [3]	test-rmse:6.37683
# [4]	test-rmse:5.81231
# [5]	test-rmse:5.31045
# [6]	test-rmse:4.86547
# [7]	test-rmse:4.47159
# [8]	test-rmse:4.12458
# [9]	test-rmse:3.81991
# [10]	test-rmse:3.5537
# [11]	test-rmse:3.32098
# [12]	test-rmse:3.11907
# [13]	test-rmse:2.94446
# [14]	test-rmse:2.79358
# [15]	test-rmse:2.66304
# [16]	test-rmse:2.55128
# [17]	test-rmse:2.45543
# [18]	test-rmse:2.37455
# [19]	test-rmse:2.30661
# [20]	test-rmse:2.2487
# [21]	test-rmse:2.20001
# [22]	test-rmse:2.15786
# [23]	test-rmse:2.12087
# [24]	test-rmse:2.09057
# [25]	test-rmse:2.06443
# [26]	test-rmse:2.04332
# [27]	test-rmse:2.02449
# [28]	test-rmse:2.00913
# [29]	test-rmse:1.9948
# [30]	test-rmse:1.98343
# [31]	test-rmse:1.97362
# [32]	test-rmse:1.96383
# [33]	test-rmse:1.95533
# [34]	test-rmse:1.94764
# [35]	test-rmse:1.9411
# [36]	test-rmse:1.93574
# [37]	test-rmse:1.93106
# [38]	test-rmse:1.92682
# [39]	test-rmse:1.92316
# [40]	test-rmse:1.91777
# [41]	test-rmse:1.91471
# [42]	test-rmse:1.91085
# [43]	test-rmse:1.90746
# [44]	test-rmse:1.90538
# [45]	test-rmse:1.90012
# [46]	test-rmse:1.89707
# [47]	test-rmse:1.89514
# [48]	test-rmse:1.89241
# [49]	test-rmse:1.89019
# [50]	test-rmse:1.88837
# [51]	test-rmse:1.88613
# [52]	test-rmse:1.88239
# [53]	test-rmse:1.88038
# [54]	test-rmse:1.87913
# [55]	test-rmse:1.8777
# [56]	test-rmse:1.87614
# [57]	test-rmse:1.87319
# [58]	test-rmse:1.87231
# [59]	test-rmse:1.87131
# [60]	test-rmse:1.8684
# [61]	test-rmse:1.86738
# [62]	test-rmse:1.86638
# [63]	test-rmse:1.86368
# [64]	test-rmse:1.86285
# [65]	test-rmse:1.86109
# [66]	test-rmse:1.85922
# [67]	test-rmse:1.8571
# [68]	test-rmse:1.85621
# [69]	test-rmse:1.85577
# [70]	test-rmse:1.85475
# [71]	test-rmse:1.8536
# [72]	test-rmse:1.85268
# [73]	test-rmse:1.85099
# [74]	test-rmse:1.85065
# [75]	test-rmse:1.8493
# [76]	test-rmse:1.84848
# [77]	test-rmse:1.84692
# [78]	test-rmse:1.84631
# [79]	test-rmse:1.84576
# [80]	test-rmse:1.84461
# [81]	test-rmse:1.84284
# [82]	test-rmse:1.84238
# [83]	test-rmse:1.8418
# [84]	test-rmse:1.84151
# [85]	test-rmse:1.84047
# [86]	test-rmse:1.83958
# [87]	test-rmse:1.83864
# [88]	test-rmse:1.83759
# [89]	test-rmse:1.83707
# [90]	test-rmse:1.83623
# [91]	test-rmse:1.83571
# [92]	test-rmse:1.83531
# [93]	test-rmse:1.83483
# [94]	test-rmse:1.83325
# [95]	test-rmse:1.83221
# [96]	test-rmse:1.8318
# [97]	test-rmse:1.83015
# [98]	test-rmse:1.82861
# [99]	test-rmse:1.8284
# [100]	test-rmse:1.8278
# [101]	test-rmse:1.82724
# [102]	test-rmse:1.82663
# [103]	test-rmse:1.82536
# [104]	test-rmse:1.82463
# [105]	test-rmse:1.82422
# [106]	test-rmse:1.82396
# [107]	test-rmse:1.82367
# [108]	test-rmse:1.82328
# [109]	test-rmse:1.82301
# [110]	test-rmse:1.82269
# [111]	test-rmse:1.82225
# [112]	test-rmse:1.82195
# [113]	test-rmse:1.82138
# [114]	test-rmse:1.82065
# [115]	test-rmse:1.82046
# [116]	test-rmse:1.81995
# [117]	test-rmse:1.81963
# [118]	test-rmse:1.8192
# [119]	test-rmse:1.81872
# [120]	test-rmse:1.81865
# [121]	test-rmse:1.81835
# [122]	test-rmse:1.81803
# [123]	test-rmse:1.81725
# [124]	test-rmse:1.81642
# [125]	test-rmse:1.81636
# [126]	test-rmse:1.81579
# [127]	test-rmse:1.8156
# [128]	test-rmse:1.81493
# [129]	test-rmse:1.8147
# [130]	test-rmse:1.81462
# [131]	test-rmse:1.81377
# [132]	test-rmse:1.8135
# [133]	test-rmse:1.81327
# [134]	test-rmse:1.81299
# [135]	test-rmse:1.81244
# [136]	test-rmse:1.81218
# [137]	test-rmse:1.8121
# [138]	test-rmse:1.8115
# [139]	test-rmse:1.81129
# [140]	test-rmse:1.81097
# [141]	test-rmse:1.81069
# [142]	test-rmse:1.80946
# [143]	test-rmse:1.80911
# [144]	test-rmse:1.80841
# [145]	test-rmse:1.80784
# [146]	test-rmse:1.80765
# [147]	test-rmse:1.80771
# [148]	test-rmse:1.80766
# [149]	test-rmse:1.80715
# [150]	test-rmse:1.80715
# [151]	test-rmse:1.80692
# [152]	test-rmse:1.80576
# [153]	test-rmse:1.80535
# [154]	test-rmse:1.80514
# [155]	test-rmse:1.80508
# [156]	test-rmse:1.80437
# [157]	test-rmse:1.80425
# [158]	test-rmse:1.80358
# [159]	test-rmse:1.80238
# [160]	test-rmse:1.80221
# [161]	test-rmse:1.8022
# [162]	test-rmse:1.8016
# [163]	test-rmse:1.80158
# [164]	test-rmse:1.80144
# [165]	test-rmse:1.80061
# [166]	test-rmse:1.80057
# [167]	test-rmse:1.80042
# [168]	test-rmse:1.7999
# [169]	test-rmse:1.79959
# [170]	test-rmse:1.79959
# [171]	test-rmse:1.7994
# [172]	test-rmse:1.79932
# [173]	test-rmse:1.79929
# [174]	test-rmse:1.79917
# [175]	test-rmse:1.79917
# [176]	test-rmse:1.79897
# [177]	test-rmse:1.79868
# [178]	test-rmse:1.79852
# [179]	test-rmse:1.79848
# [180]	test-rmse:1.79795
# [181]	test-rmse:1.79741
# [182]	test-rmse:1.79689
# [183]	test-rmse:1.79655
# [184]	test-rmse:1.7963
# [185]	test-rmse:1.79615
# [186]	test-rmse:1.79591
# [187]	test-rmse:1.79576
# [188]	test-rmse:1.7956
# [189]	test-rmse:1.79542
# [190]	test-rmse:1.7954
# [191]	test-rmse:1.79535
# [192]	test-rmse:1.79502
# [193]	test-rmse:1.79497
# [194]	test-rmse:1.79502
# [195]	test-rmse:1.79483
# [196]	test-rmse:1.79479
# [197]	test-rmse:1.79468
# [198]	test-rmse:1.79436
# [199]	test-rmse:1.79394
# [200]	test-rmse:1.79392
# [201]	test-rmse:1.7937
# [202]	test-rmse:1.79344
# [203]	test-rmse:1.79308
# [204]	test-rmse:1.79255
# [205]	test-rmse:1.79212
# [206]	test-rmse:1.79206
# [207]	test-rmse:1.79203
# [208]	test-rmse:1.79163
# [209]	test-rmse:1.79131
# [210]	test-rmse:1.79126
# [211]	test-rmse:1.79087
# [212]	test-rmse:1.7908
# [213]	test-rmse:1.79057
# [214]	test-rmse:1.79012
# [215]	test-rmse:1.78972
# [216]	test-rmse:1.78905
# [217]	test-rmse:1.78867
# [218]	test-rmse:1.78866
# [219]	test-rmse:1.78862
# [220]	test-rmse:1.78861
# [221]	test-rmse:1.78855
# [222]	test-rmse:1.78829
# [223]	test-rmse:1.78825
# [224]	test-rmse:1.788
# [225]	test-rmse:1.7875
# [226]	test-rmse:1.7873
# [227]	test-rmse:1.78719
# [228]	test-rmse:1.7872
# [229]	test-rmse:1.78721
# [230]	test-rmse:1.78706
# [231]	test-rmse:1.78678
# [232]	test-rmse:1.78615
# [233]	test-rmse:1.78604
# [234]	test-rmse:1.78606
# [235]	test-rmse:1.78613
# [236]	test-rmse:1.78598
# [237]	test-rmse:1.78592
# [238]	test-rmse:1.78588
# [239]	test-rmse:1.78553
# [240]	test-rmse:1.7855
# [241]	test-rmse:1.78557
# [242]	test-rmse:1.78522
# [243]	test-rmse:1.78453
# [244]	test-rmse:1.78443
# [245]	test-rmse:1.78415
# [246]	test-rmse:1.78417
# [247]	test-rmse:1.78417
# [248]	test-rmse:1.78373
# [249]	test-rmse:1.78345
# [250]	test-rmse:1.78337
# [251]	test-rmse:1.78339
# [252]	test-rmse:1.78337
# [253]	test-rmse:1.78327
# [254]	test-rmse:1.78331
# [255]	test-rmse:1.7833
# [256]	test-rmse:1.78296
# [257]	test-rmse:1.78279
# [258]	test-rmse:1.78241
# [259]	test-rmse:1.78227
# [260]	test-rmse:1.78213
# [261]	test-rmse:1.78216
# [262]	test-rmse:1.78203
# [263]	test-rmse:1.78205
# [264]	test-rmse:1.78184
# [265]	test-rmse:1.78186
# [266]	test-rmse:1.78181
# [267]	test-rmse:1.78176
# [268]	test-rmse:1.78154
# [269]	test-rmse:1.78129
# [270]	test-rmse:1.78133
# [271]	test-rmse:1.78137
# [272]	test-rmse:1.78122
# [273]	test-rmse:1.78125
# [274]	test-rmse:1.78119
# [275]	test-rmse:1.78117
# [276]	test-rmse:1.78073
# [277]	test-rmse:1.78079
# [278]	test-rmse:1.78077
# [279]	test-rmse:1.78076
# [280]	test-rmse:1.78074
# [281]	test-rmse:1.78068
# [282]	test-rmse:1.78063
# [283]	test-rmse:1.78066
# [284]	test-rmse:1.78034
# [285]	test-rmse:1.78005
# [286]	test-rmse:1.78003
# [287]	test-rmse:1.78005
# [288]	test-rmse:1.77988
# [289]	test-rmse:1.77973
# [290]	test-rmse:1.77941
# [291]	test-rmse:1.77949
# [292]	test-rmse:1.77945
# [293]	test-rmse:1.7793
# [294]	test-rmse:1.77921
# [295]	test-rmse:1.77906
# [296]	test-rmse:1.77832
# [297]	test-rmse:1.77829
# [298]	test-rmse:1.77795
# [299]	test-rmse:1.77792
# [300]	test-rmse:1.77794
# [301]	test-rmse:1.77733
# [302]	test-rmse:1.77727
# [303]	test-rmse:1.77702
# [304]	test-rmse:1.77687
# [305]	test-rmse:1.7769
# [306]	test-rmse:1.77665
# [307]	test-rmse:1.77624
# [308]	test-rmse:1.77597
# [309]	test-rmse:1.77577
# [310]	test-rmse:1.77578
# [311]	test-rmse:1.77568
# [312]	test-rmse:1.77574
# [313]	test-rmse:1.77574
# [314]	test-rmse:1.77579
# [315]	test-rmse:1.77574
# [316]	test-rmse:1.77574
# Stopping. Best iteration:
# [311]	test-rmse:1.77568

# %%
gridsearch_params = [
    (max_depth, eta)
    for max_depth in [6, 7, 8]
    for eta in [0.1, 0.05, 0.01]
]
gridsearch_params
# Out:
# [(6, 0.1),
#  (6, 0.05),
#  (6, 0.01),
#  (7, 0.1),
#  (7, 0.05),
#  (7, 0.01),
#  (8, 0.1),
#  (8, 0.05),
#  (8, 0.01)]

# %%
cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=10,
        seed=0,
        nfold=5,
        metrics={'rmse'},
        early_stopping_rounds=5
    )

# %%
cv_results
# Out:
#    test-rmse-mean  test-rmse-std  train-rmse-mean  train-rmse-std
# 0        8.504555       0.017968         8.504422        0.004390
# 1        7.711653       0.016784         7.711201        0.004017
# 2        7.003183       0.015716         7.002686        0.003723
# 3        6.371595       0.014902         6.370670        0.003449
# 4        5.809256       0.014146         5.807937        0.003217
# 5        5.309430       0.013949         5.307730        0.002885
# 6        4.866538       0.013580         4.864481        0.002682
# 7        4.474677       0.012941         4.472223        0.002667
# 8        4.129364       0.012621         4.126518        0.002511
# 9        3.826270       0.012058         3.822876        0.002426

# %%
min_rmse = float('Inf')
best_param = []

for max_depth, eta in gridsearch_params:
    print('max_depth={}, eta={}'.format(max_depth, eta))
    
    params['max_depth'] = max_depth
    params['eta'] = eta
    
    cv_results = xgb.cv(
        params,
        dtrain,
        num_boost_round=1000,
        seed=0,
        nfold=5,
        metrics={'rmse'},
        early_stopping_rounds=5
    )
    
    mean_rmse = cv_results['test-rmse-mean'].min()
    boost_rounds = cv_results['test-rmse-mean'].argmin()
    print('RMSE {} for {} rounds'.format(mean_rmse, boost_rounds))
    if mean_rmse < min_rmse:
        min_rmse = mean_rmse
        best_param = (max_depth, eta)
    
print('Best params {}, RMSE {}'.format(best_param, min_rmse))

# %%
params['max_depth'] = 8
params['eta'] = 0.01

model = xgb.train(params=params,
                  dtrain=dtrain,
                  num_boost_round=1000,
                  early_stopping_rounds=5,
                  evals=[(dtest, 'test')])

# %%
prediction = model.predict(xgb.DMatrix(X_test), 
                           ntree_limit=model.best_ntree_limit)

plt.figure(figsize=(12, 12))
plt.scatter(y_test[:1000], prediction[:1000], alpha=0.2)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 12))
xgb.plot_importance(model, max_num_features=12, height=0.8, ax=ax)
plt.show()
